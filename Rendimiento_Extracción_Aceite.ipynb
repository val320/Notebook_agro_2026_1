# %% [markdown]
# <a href="https://colab.research.google.com/github/val320/Notebook_agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **planteamiento**:
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
#
# $$pa = lt * 0.92$$
#
# $$r =(pa/pr)*100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Ingresa Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float). (pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre = input("Ingrese el nombre del lote de producción: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

# PROCESO: Calcular peso del aceite (pa) y el rendimiento(r)
pa = lt * 0.92
r = (pa/pr)*100

# SALIDA: Informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote de producción: El perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote El perico  es del 18.4 %

# %% [markdown]
# ```markdown
# ## Explicación del Código
#
# Este bloque de código realiza el cálculo del Índice de Rendimiento de Extracción (IRE) para una planta procesadora de palma de aceite.
#
# ```python
# # ENTRADA: Ingresa Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float). (pr)
# # Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# * Estas líneas son comentarios que describen las siguientes variables que se van a solicitar al usuario: el nombre del lote, el peso de los racimos en kilogramos (`pr`) y los litros de aceite obtenidos (`lt`).
#
# ```python
# nombre = input("Ingrese el nombre del lote de producción: ")
# ```
# * Solicita al usuario que ingrese el nombre del lote de producción. La entrada del usuario se almacena como una cadena de texto en la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# * Solicita al usuario que ingrese el peso de los racimos en kilogramos. La función `input()` lee la entrada como una cadena, y `float()` la convierte a un número decimal (`float`) antes de almacenarla en la variable `pr`.
#
# ```python
# lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
# ```
# * Solicita al usuario que ingrese la cantidad de aceite crudo obtenido en litros. Similar a la línea anterior, la entrada se convierte a un número decimal (`float`) y se guarda en la variable `lt`.
#
# ```python
# # PROCESO: Calcular peso del aceite (pa) y el rendimiento(r)
# ```
# * Este es un comentario que indica que las siguientes líneas realizarán los cálculos necesarios.
#
# ```python
# pa = lt * 0.92
# ```
# * Calcula el peso del aceite (`pa`) en kilogramos. Se multiplica la cantidad de litros de aceite (`lt`) por su densidad aproximada (0.92 kg/L).
#
# ```python
# r = (pa/pr)*100
# ```
# * Calcula el Índice de Rendimiento de Extracción (`r`). Se divide el peso del aceite (`pa`) entre el peso de los racimos (`pr`) y el resultado se multiplica por 100 para obtener un porcentaje.
#
# ```python
# # SALIDA: Informar el rendimiento del lote
# ```
# * Este es un comentario que indica que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# * Imprime en la consola el rendimiento calculado. Utiliza las variables `nombre` y `r` para formar un mensaje informativo que muestra el nombre del lote y su rendimiento porcentual.
# ```
